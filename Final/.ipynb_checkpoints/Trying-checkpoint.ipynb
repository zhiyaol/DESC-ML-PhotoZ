# %%
import Train

# %%
Model_table = Train.multiple_train(1)
# Out:
# /global/common/software/lsst/common/miniconda/py3-4.5.12/envs/stack/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
Model_table

# %%
model_table = Train.Table(Model_table)
# How to save the models which are Class objects
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f81cd2f5be22> in <module>
# ----> 1 model_table = Train.Table(Model_table)
#
# /global/common/software/lsst/common/miniconda/py3-4.5.12/envs/stack/lib/python3.7/site-packages/astropy/table/table.py in __init__(self, data, masked, names, dtype, meta, copy, rows, copy_indices, **kwargs)
#     409
#     410         # Finally do the real initialization
# --> 411         init_func(data, names, dtype, n_cols, copy)
#     412
#     413         # Whatever happens above, the masked property should be set to a boolean
#
# /global/common/software/lsst/common/miniconda/py3-4.5.12/envs/stack/lib/python3.7/site-packages/astropy/table/table.py in _init_from_list(self, data, names, dtype, n_cols, copy)
#     685                                        copy=copy, copy_indices=self._init_indices)
#     686             else:
# ...

# %%
#result_loc = '/global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/OLIVIA_WORK/result3-101-0-3.fits'
result_loc = 'try.fits'
model_table.write(result_loc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c82dbeeec108> in <module>
#       1 #result_loc = '/global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/OLIVIA_WORK/result3-101-0-3.fits'
#       2 result_loc = 'try.fits'
# ----> 3 Model_table.write(result_loc)
#
# AttributeError: 'list' object has no attribute 'write'
